# %%
import pandas as pd
import duckdb
import pandera

print("Entorno configurado correctamente")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import duckdb
#       3 import pandera
#       4
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv("../data/raw/servicios.csv")

df.head()

# %%
duckdb.sql("""
    SELECT *
    FROM '../data/raw/servicios.csv'
    LIMIT 5
""")
